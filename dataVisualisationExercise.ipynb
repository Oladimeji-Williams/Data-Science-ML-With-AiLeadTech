# %% [raw]
# Exercise 1 (Using Gapminder Data)
# Questions:
#     1. Find the number of features with missing values and include the missing values for each
#     2. How many rows and columns are in the data
#     3. Find the average GDP for the year 2006
#     4. Find the total GDP for each region for the year 2006
#     5. Fill the NAs in Child mortality and Fertility with 0, Population and gdp with its median
#     6. Create a bar graph/plot to visualize the GDP for each region in the year 2006 ( Try to rotate the xticks to avoid any
#             overlap in the labels)
#             label: x-axis = Region, y-axis = GDP, title = Plot of GDP for each region

# %%
# Exercise 1, number 1
import pandas as pd
gapminder_wide = pd.read_csv(r"C:\Users\Williams\Desktop\DataScienceWithAiLead\data\gapminder.CSV")
gapminder_wide.isnull().sum()
# Out:
# country      0
# continent    0
# year         0
# lifeExp      0
# pop          0
# gdpPercap    0
# dtype: int64

# %%
# Exercise 1, number 2
gapminder_wide.shape
# Out:
# (1704, 6)

# %%
# Exercise 1, number 3
gapminder_wide.groupby(["year"])["gdpPercap"].mean().loc[2007]
# 2006 is not listed with data in the raw data
# Out:
# 11680.071819878172

# %%
# Exercise 1, number 4
gapminder_wide.groupby(["year"])["gdpPercap"].sum().loc[2007]
# Out:
# 1658570.1984227004

# %%
#Exercise 2, number 1
import pandas as pd
names_wide = pd.read_csv(r"C:\Users\Williams\Desktop\DataScienceWithAiLead\data\Names.csv")
names_wide.rename({"John":"First_name", "Doe":"Last_name", "120 jefferson st.":"Address", "Riverside":"City", " NJ":"State", "8074":"Area_code", "45000":"Income"}, axis=1)
# Out:
#              First_name Last_name                           Address  \
# 0                  Jack  McGinnis                      220 hobo Av.
# 1         John "Da Man"    Repici                 120 Jefferson St.
# 2               Stephen     Tyler  7452 Terrace "At the Plaza" road
# 3                 Chris  Blankman                               NaN
# 4   Joan "Danger", Anne       Jet               9th, at Terrace plc
# 5                   Ben       Doe                 120 jefferson st.
# 6                Audrey  Oweimrin                      220 hobo Av.
# 7                Benson    Greene                 120 Jefferson St.
# 8               Stephen    Tybert  7452 Terrace "At the Plaza" road
# 9                   Dan  Blankman                               NaN
# 10            Catherine       Jet               9th, at Terrace plc
# 11                Tyler    Taylor            106, Grant Chamberlain
#
#            City State  Area_code  Income
# ...

# %%
#Exercise 2, number 2
import pandas as pd
names_new = names_wide.rename({"John":"First_name", "Doe":"Last_name", "120 jefferson st.":"Address", "Riverside":"City", " NJ":"State", "8074":"Area_code", "45000":"Income"}, axis=1)
tax_range = {range(10000, 40001):0.25, range(40001, 80001):0.30, range(80001,max(names_new["Income"])+1):0.35}
names_new["Tax"] = names_new["Income"].apply(lambda x: next(v for k, v in tax_range.items() if x in k))
names_new
# Out:
#              First_name Last_name                           Address  \
# 0                  Jack  McGinnis                      220 hobo Av.
# 1         John "Da Man"    Repici                 120 Jefferson St.
# 2               Stephen     Tyler  7452 Terrace "At the Plaza" road
# 3                 Chris  Blankman                               NaN
# 4   Joan "Danger", Anne       Jet               9th, at Terrace plc
# 5                   Ben       Doe                 120 jefferson st.
# 6                Audrey  Oweimrin                      220 hobo Av.
# 7                Benson    Greene                 120 Jefferson St.
# 8               Stephen    Tybert  7452 Terrace "At the Plaza" road
# 9                   Dan  Blankman                               NaN
# 10            Catherine       Jet               9th, at Terrace plc
# 11                Tyler    Taylor            106, Grant Chamberlain
#
#            City State  Area_code  Income   Tax
# ...

# %%
#Exercise 2, number 3
import pandas as pd
shifts_wide = pd.read_excel(r"C:\Users\Williams\Desktop\DataScienceWithAiLead\data\shifts.xlsx")
shifts_wide.groupby("Region")["Units Sold"].sum()
# Out:
# Region
# East     14228
# North    14675
# South    13752
# West     11255
# Name: Units Sold, dtype: int64

# %%
#Exercise 2, number 4
shifts_wide.groupby("Sales Rep")["Units Sold"].sum().sort_values(ascending=False).head(3)
# Out:
# Sales Rep
# Deandra     2915
# Jesusita    2116
# Natashia    2082
# Name: Units Sold, dtype: int64

# %%
#Exercise 3, number 1
titanic_wide = pd.read_csv(r"C:\Users\Williams\Desktop\DataScienceWithAiLead\data\titanic.csv")
titanic_wide.shape
titanic_wide
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...
